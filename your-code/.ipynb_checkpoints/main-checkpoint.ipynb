# %%
import pandas as pd
import numpy as np
import io
pd.set_option('display.max_columns',None)

# %%
path = r'C:\Users\jvaym\Desktop\IRONHACK\Semana2\SHARKS-_IN_DISGUISE\Data\attacks.csv'
with open(path, encoding='utf8', errors='ignore') as f:
    data = f.read()

data2 = io.StringIO(data)
df = pd.read_csv(data2, sep=",") # Este es el Data Frame original
columns = list(df.columns) # Aquí tenemos una lista con los nombres de las columnas

# %%
df.shape
# Out:
# (25723, 24)

# %%
df
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
df.drop('Unnamed: 23', axis = 1, inplace = True) #Esto se ejecuta 1 vez solo
df
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
df['Unnamed: 22'].fillna(0.0, inplace=True)
df.isna().sum() #Le hemos sustituido los valores nulos de la columna 23 por 0.0
# Out:
# Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# Unnamed: 22                   0
# dtype: int64

# %%
pd.options.display.max_rows = 500
pd.options.display.max_rows
# Out:
# 500

# %%
pd.set_option('display.max_rows', 500)

# %%
columns = list(df.columns)
columns # Esta es la nueva lista de columnas
print(df.nunique()) #Estos son los valores unicos
# Out:
# Case Number               6287
# Date                      5433
# Year                       249
# Type                         8
# Country                    212
# Area                       825
# Location                  4101
# Activity                  1532
# Name                      5230
# Sex                          6
# Age                        155
# Injury                    3737
# Fatal (Y/N)                  8
# Time                       365
# Species                   1547
# Investigator or Source    4969
# pdf                       6291
# href formula              6290
# href                      6285
# Case Number.1             6285
# Case Number.2             6286
# original order            6308
# Unnamed: 22                  2
# dtype: int64

# %%
df.isnull().sum(axis=1)
df = df.drop(df[df.isnull().sum(axis=1) > 10].index) #Borramos las filas con más de 10 valores nulos
df.shape
# Out:
# (6302, 23)

# %%
f1 = df.to_excel(r'C:\Users\jvaym\Desktop\IRONHACK\Semana2\SHARKS-_IN_DISGUISE\your-code\Sharks_v1.xls', index=False)
# Out:
# C:\Users\jvaym\AppData\Local\Temp/ipykernel_8752/2989725286.py:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   f1 = df.to_excel(r'C:\Users\jvaym\Desktop\IRONHACK\Semana2\SHARKS-_IN_DISGUISE\your-code\Sharks_v1.xls', index=False)

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6302 entries, 0 to 6301
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             6301 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
df['Case Number'].nunique()
# Out:
# 6285

# %%
df['Case Number'].fillna("unkown", inplace = True) #Cambiamos los valores nulos por unknown
df.isna().sum()
df.duplicated().any() #No hay duplicados en esta columna.
# Out:
# False

# %%
df['Year'].fillna("unkown", inplace = True)
df['Year'].isna().sum()
# Out:
# 0

# %%
#type(df['Year'])

# %%
#df = df.astype({"Year": int}, errors='raise') 
df.dtypes
# Out:
# Case Number                object
# Date                       object
# Year                       object
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Time                       object
# Species                    object
# Investigator or Source     object
# pdf                        object
# href formula               object
# href                       object
# Case Number.1              object
# Case Number.2              object
# original order            float64
# Unnamed: 22                object
# dtype: object

# %%
df['Year'][187] = 0
df['Year'][6079] = 0

df['Year'] = pd.to_numeric(df['Year'], downcast='integer') #Pasamos toda la columna a integer
df['original order'] = pd.to_numeric(df['Year'], downcast='integer') #Pasamos toda la columna a integer
# Out:
# C:\Users\jvaym\AppData\Local\Temp/ipykernel_8752/1080190561.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year'][187] = 0
# C:\Users\jvaym\AppData\Local\Temp/ipykernel_8752/1080190561.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year'][6079] = 0

# %%
#df = pd.to_numeric(df['Year'], downcast='integer')
df.dtypes
# Out:
# Case Number               object
# Date                      object
# Year                       int16
# Type                      object
# Country                   object
# Area                      object
# Location                  object
# Activity                  object
# Name                      object
# Sex                       object
# Age                       object
# Injury                    object
# Fatal (Y/N)               object
# Time                      object
# Species                   object
# Investigator or Source    object
# pdf                       object
# href formula              object
# href                      object
# Case Number.1             object
# Case Number.2             object
# original order             int16
# Unnamed: 22               object
# dtype: object

# %%
df['Type'].fillna("unkown", inplace = True) #Rellenamos los nulos con Unknown
df['Country'].fillna("unkown", inplace = True) #Rellenamos los nulos con Unknown
df['Area'].fillna("unkown", inplace = True) #Rellenamos los nulos con Unknown
df['Location'].fillna("unkown", inplace = True) #Rellenamos los nulos con Unknown
df['Activity'].fillna("unkown", inplace = True) #Rellenamos los nulos con Unknown
df['Name'].fillna("unkown", inplace = True) #Rellenamos los nulos con Unknown
df['Sex '].fillna("unkown", inplace = True) #Rellenamos los nulos con Unknown
df['Age'].fillna(0, inplace = True) #Rellenamos los nulos con 0
df['Injury'].fillna("unkown", inplace = True) #Rellenamos los nulos con Unknown
df['Fatal (Y/N)'].fillna("unkown", inplace = True) #Rellenamos los nulos con Unknown
df['Time'].fillna("unkown", inplace = True) #Rellenamos los nulos con Unknown
df['Species '].fillna("unkown", inplace = True) #Rellenamos los nulos con Unknown
df['Investigator or Source'].fillna("unkown", inplace = True) #Rellenamos los nulos con Unknown
df['href formula'].fillna("unkown", inplace = True) #Rellenamos los nulos con Unknown




df.isna().sum()
# Out:
# Case Number               0
# Date                      0
# Year                      0
# Type                      0
# Country                   0
# Area                      0
# Location                  0
# Activity                  0
# Name                      0
# Sex                       0
# Age                       0
# Injury                    0
# Fatal (Y/N)               0
# Time                      0
# Species                   0
# Investigator or Source    0
# pdf                       0
# href formula              0
# href                      0
# Case Number.1             0
# Case Number.2             0
# original order            0
# Unnamed: 22               0
# dtype: int64

# %%
f2 = df.to_excel(r'C:\Users\jvaym\Desktop\IRONHACK\Semana2\SHARKS-_IN_DISGUISE\your-code\Sharks_v2.xls', index=False)
# Out:
# C:\Users\jvaym\AppData\Local\Temp/ipykernel_8752/131842214.py:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   f2 = df.to_excel(r'C:\Users\jvaym\Desktop\IRONHACK\Semana2\SHARKS-_IN_DISGUISE\your-code\Sharks_v2.xls', index=False)

# %%
df.Age.unique()
# Out:
# array(['57', '11', '48', 0, '18', '52', '15', '12', '32', '10', '21',
#        '34', '30', '60', '33', '29', '54', '41', '37', '56', '19', '25',
#        '69', '38', '55', '35', '46', '45', '14', '40s', '28', '20', '24',
#        '26', '49', '22', '7', '31', '17', '40', '13', '42', '3', '8',
#        '50', '16', '82', '73', '20s', '68', '51', '39', '58', 'Teen',
#        '47', '61', '65', '36', '66', '43', '60s', '9', '72', '59', '6',
#        '27', '64', '23', '71', '44', '62', '63', '70', '18 months', '53',
#        '30s', '50s', 'teen', '77', '74', '28 & 26', '5', '86', '18 or 20',
#        '12 or 13', '46 & 34', '28, 23 & 30', 'Teens', '36 & 26',
#        '8 or 10', '84', ' ', '30 or 36', '21 & ?', '75', '33 or 37',
#        'mid-30s', '23 & 20', ' 30', '7      &    31', ' 28', '20?',
#        "60's", '32 & 30', '16 to 18', '87', '67', 'Elderly', 'mid-20s',
#        'Ca. 33', '74 ', '45 ', '21 or 26', '20 ', '>50', '18 to 22',
# ...

# %%
df['Age'][48] = 40
df['Age'][150] = 20
df['Age'][194] = 40
for i in range(len(df['Age'])): #Convertimos los valores a integer
    try:
        df['Age'][i] = int(df['Age'][i])
        #print(df['Age'][i])
    except:
        #print(df['Age'][i])
        df['Age'][i] = 0
# Out:
# C:\Users\jvaym\AppData\Local\Temp/ipykernel_8752/3863377215.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'][48] = 40
# C:\Users\jvaym\AppData\Local\Temp/ipykernel_8752/3863377215.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'][150] = 20
# C:\Users\jvaym\AppData\Local\Temp/ipykernel_8752/3863377215.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'][194] = 40
# ...

# %%
df.dtypes
# Out:
# Case Number               object
# Date                      object
# Year                       int16
# Type                      object
# Country                   object
# Area                      object
# Location                  object
# Activity                  object
# Name                      object
# Sex                       object
# Age                       object
# Injury                    object
# Fatal (Y/N)               object
# Time                      object
# Species                   object
# Investigator or Source    object
# pdf                       object
# href formula              object
# href                      object
# Case Number.1             object
# Case Number.2             object
# original order             int16
# Unnamed: 22               object
# dtype: object

# %%
df['Age'] = pd.to_numeric(df['Age'], downcast='integer')

df.dtypes
# Out:
# Case Number               object
# Date                      object
# Year                       int16
# Type                      object
# Country                   object
# Area                      object
# Location                  object
# Activity                  object
# Name                      object
# Sex                       object
# Age                         int8
# Injury                    object
# Fatal (Y/N)               object
# Time                      object
# Species                   object
# Investigator or Source    object
# pdf                       object
# href formula              object
# href                      object
# Case Number.1             object
# Case Number.2             object
# original order             int16
# Unnamed: 22               object
# dtype: object

# %%
df.drop(df[df['Fatal (Y/N)'] == 'unkown'].index, axis=0, inplace=True) #Si no sabemos si murieron o no, no nos sirve
df.shape
# Out:
# (5763, 23)

# %%
f3 = df.to_excel(r'C:\Users\jvaym\Desktop\IRONHACK\Semana2\SHARKS-_IN_DISGUISE\your-code\Sharks_v3.xls', index=False)
# Out:
# C:\Users\jvaym\AppData\Local\Temp/ipykernel_8752/1570059361.py:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   f3 = df.to_excel(r'C:\Users\jvaym\Desktop\IRONHACK\Semana2\SHARKS-_IN_DISGUISE\your-code\Sharks_v3.xls', index=False)

# %%
df.drop(df[df['Country'] == 'unkown'].index, axis=0, inplace=True) # Nos deshacemos de las filas que no tengan País.

# %%
df.shape
# Out:
# (5718, 23)

# %%
countries = list(df['Country'].unique())
countries
# Out:
# ['USA',
#  'AUSTRALIA',
#  'MEXICO',
#  'BRAZIL',
#  'ENGLAND',
#  'SOUTH AFRICA',
#  'THAILAND',
#  'COSTA RICA',
#  'MALDIVES',
#  'BAHAMAS',
#  'NEW CALEDONIA',
#  'ECUADOR',
#  'MALAYSIA',
#  'LIBYA',
#  'CUBA',
#  'MAURITIUS',
#  'NEW ZEALAND',
#  'SPAIN',
#  'SAMOA',
#  'SOLOMON ISLANDS',
#  'JAPAN',
#  'EGYPT',
#  'ST HELENA, British overseas territory',
#  'REUNION',
#  'FRENCH POLYNESIA',
#  'UNITED KINGDOM',
#  'UNITED ARAB EMIRATES',
#  'PHILIPPINES',
#  'INDONESIA',
#  'CHINA',
#  'COLUMBIA',
#  'Fiji',
#  'DOMINICAN REPUBLIC',
#  'ARUBA',
#  'MOZAMBIQUE',
#  'FIJI',
#  'PUERTO RICO',
#  'ATLANTIC OCEAN',
#  'GREECE',
#  'ST. MARTIN',
#  'FRANCE',
#  'PAPUA NEW GUINEA',
#  'TRINIDAD & TOBAGO',
#  'KIRIBATI',
#  'ISRAEL',
#  'DIEGO GARCIA',
#  'TAIWAN',
#  'PALESTINIAN TERRITORIES',
#  'GUAM',
#  'SEYCHELLES',
#  'BELIZE',
#  'JAMAICA',
#  'NIGERIA',
#  'TONGA',
#  'SCOTLAND',
#  'ITALY',
#  'CHILE',
#  'KENYA',
#  'RUSSIA',
#  'TURKS & CAICOS',
#  'AZORES',
# ...

# %%
f4 = df.to_excel(r'C:\Users\jvaym\Desktop\IRONHACK\Semana2\SHARKS-_IN_DISGUISE\your-code\Sharks_v4.xls', index=False)
# Out:
# C:\Users\jvaym\AppData\Local\Temp/ipykernel_8752/388733388.py:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   f4 = df.to_excel(r'C:\Users\jvaym\Desktop\IRONHACK\Semana2\SHARKS-_IN_DISGUISE\your-code\Sharks_v4.xls', index=False)

# %%
for e in range(len(df['Country'])):
    x = []
    try:
        df['Country'][e] = df['Country'][e].strip()
        #print(type(df['Country'][e]))
    except:
        if type(e) == int:
            continue
# Out:
# C:\Users\jvaym\AppData\Local\Temp/ipykernel_8752/3284775654.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country'][e] = df['Country'][e].strip()

# %%
lst = []
errase_Countryinx = [] #Filas que hay que eliminar de la tabla
for e in range(len(df['Country'])):
    
    try:
        lst.append(df['Country'][e])
    except:
        if type(e) == int:
            errase_Countryinx.append(str(e))
            continue

# %%
errase_Countryint = [] #Lista de las filas a eliminar en formato enteros 
for s in errase_Countryinx:
    errase_Countryint.append(int(s))
errase_Countryint
# Out:
# [27,
#  62,
#  76,
#  79,
#  84,
#  98,
#  107,
#  115,
#  124,
#  125,
#  145,
#  151,
#  153,
#  159,
#  187,
#  189,
#  195,
#  206,
#  226,
#  265,
#  269,
#  285,
#  289,
#  291,
#  294,
#  297,
#  306,
#  307,
#  334,
#  344,
#  373,
#  378,
#  382,
#  384,
#  391,
#  392,
#  402,
#  437,
#  438,
#  456,
#  459,
#  466,
#  499,
#  507,
#  525,
#  532,
#  558,
#  570,
#  576,
#  578,
#  624,
#  633,
#  657,
#  660,
#  676,
#  688,
#  690,
#  708,
#  721,
#  732,
#  761,
#  763,
#  764,
#  768,
#  771,
#  778,
#  786,
#  814,
#  830,
#  836,
#  839,
#  859,
#  874,
#  882,
#  890,
#  926,
#  940,
#  953,
#  967,
#  994,
#  1003,
#  1044,
#  1064,
#  1069,
#  1093,
#  1107,
#  1117,
#  1118,
#  1136,
#  1138,
#  1162,
#  1167,
#  1178,
#  1212,
#  1217,
#  1219,
#  1235,
#  1240,
#  1270,
#  1271,
#  1272,
#  1273,
#  1292,
#  1295,
#  1301,
#  1304,
#  1314,
#  1326,
#  1361,
#  1366,
#  1371,
#  1381,
#  1401,
#  1407,
#  1410,
#  1427,
#  1433,
#  1441,
#  1442,
#  1456,
# ...

# %%
#df['Country'][int('27')]
#df.drop(27, axis = 0, inplace = True)

# %%
df['Country'].head(30)
# Out:
# 0              USA
# 1              USA
# 2              USA
# 3        AUSTRALIA
# 4           MEXICO
# 5        AUSTRALIA
# 6           BRAZIL
# 7              USA
# 8              USA
# 9              USA
# 10       AUSTRALIA
# 11             USA
# 12             USA
# 13         ENGLAND
# 14       AUSTRALIA
# 15    SOUTH AFRICA
# 16       AUSTRALIA
# 17        THAILAND
# 18      COSTA RICA
# 19       AUSTRALIA
# 20       AUSTRALIA
# 21       AUSTRALIA
# 22       AUSTRALIA
# 23        MALDIVES
# 24    SOUTH AFRICA
# 25             USA
# 26        THAILAND
# 28       AUSTRALIA
# 29       AUSTRALIA
# 30         BAHAMAS
# Name: Country, dtype: object

# %%
countries = list(df['Country'].unique()) # Ahora los paises están sin espacios
len(countries)
# Out:
# 190

# %%
#Nos Cargamos Todo esto
df.drop(df.loc[df['Country'] == 'ASIA?'].index[0], axis = 0, inplace = True)
df.drop(df.loc[df['Country'] == 'Between PORTUGAL & INDIA'].index[0], axis = 0, inplace = True)
df.drop(df.loc[df['Country'] == 'RED SEA?'].index[0], axis = 0, inplace = True)
df.drop(df.loc[df['Country'] == 'EQUATORIAL GUINEA / CAMEROON'].index[0], axis = 0, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8752/1507118226.py in <module>
#       1 #Nos Cargamos Todo esto
# ----> 2 df.drop(df.loc[df['Country'] == 'ASIA?'].index[0], axis = 0, inplace = True)
#       3 df.drop(df.loc[df['Country'] == 'Between PORTUGAL & INDIA'].index[0], axis = 0, inplace = True)
#       4 df.drop(df.loc[df['Country'] == 'RED SEA?'].index[0], axis = 0, inplace = True)
#       5 df.drop(df.loc[df['Country'] == 'EQUATORIAL GUINEA / CAMEROON'].index[0], axis = 0, inplace = True)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    4602         if is_scalar(key):
#    4603             key = com.cast_scalar_indexer(key, warn_float=True)
# -> 4604             return getitem(key)
#    4605
#    4606         if isinstance(key, slice):
#
# ...

# %%
#Y los que no sabemos si están vivos y muertos también
df.drop(df.loc[df['Fatal (Y/N)'] == 'UNKNOWN'].index[0], axis = 0, inplace = True)
df.drop(df.loc[df['Fatal (Y/N)'] == ' N'].index[0], axis = 0, inplace = True)
df.drop(df.loc[df['Fatal (Y/N)'] == 'M'].index[0], axis = 0, inplace = True)
df.drop(df.loc[df['Fatal (Y/N)'] == '2017'].index[0], axis = 0, inplace = True)

# %%
df_agemorezero = df.loc[df['Age'] > 0 ]

# %%
round(df_agemorezero.Age.mean())

print("The average age of the ones atacked is",round(df_agemorezero.Age.mean()) )
# Out:
# The average age of the ones atacked is 27

# %%
df_dead = df_agemorezero.loc[df_agemorezero['Fatal (Y/N)'] == 'Y']
df_Ndead = df_agemorezero.loc[df_agemorezero['Fatal (Y/N)'] == 'N']
#df_ny = df_agemorezero.loc[df_agemorezero['Fatal (Y/N)'] == 'N' & 'Y']
df_dead['Fatal (Y/N)'].value_counts() #¿Cuantos han muerto por ataques de tiburon?
df_Ndead['Fatal (Y/N)'].value_counts() #¿Cuantos han sobrevivido por ataques de tiburon?
df['Fatal (Y/N)'].value_counts()
# Out:
# N          4272
# Y          1362
# UNKNOWN      67
#  N            6
# N             1
# y             1
# Name: Fatal (Y/N), dtype: int64

# %%
df_agemorezero.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22'],
#       dtype='object')

# %%
df.drop(df.loc[df['Fatal (Y/N)'] == 'UNKNOWN'].index[0], axis = 0, inplace = True)
df['Fatal (Y/N)'].value_counts()
# Out:
# N          4272
# Y          1362
# UNKNOWN      66
#  N            6
# N             1
# y             1
# Name: Fatal (Y/N), dtype: int64

# %%
df_dead.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22'],
#       dtype='object')

# %%
df_ny = pd.concat([df_dead,df_Ndead], axis = 0)
type(df_Ndead)
# Out:
# pandas.core.frame.DataFrame

# %%
df_ny['Fatal (Y/N)'].value_counts()
# Out:
# N    2540
# Y     593
# Name: Fatal (Y/N), dtype: int64

# %%
f5 = df_ny.to_excel(r'C:\Users\jvaym\Desktop\IRONHACK\Semana2\SHARKS-_IN_DISGUISE\your-code\Sharks_v5.xls', index=False)
# Out:
# C:\Users\jvaym\AppData\Local\Temp/ipykernel_8752/1386852371.py:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   f5 = df_ny.to_excel(r'C:\Users\jvaym\Desktop\IRONHACK\Semana2\SHARKS-_IN_DISGUISE\your-code\Sharks_v5.xls', index=False)

# %%
# Edad media de los atacados
mean_Atacked = df_ny.loc[df_ny['Age'] > 0 ]
print("La edad media de edad de los atacados son",round(mean_Atacked['Age'].mean()),"años")
# Out:
# La edad media de edad de los atacados son 27 años

# %%
#% muertos por ataque
len(df_ny)
x = df_ny.loc[df_ny['Fatal (Y/N)'] == 'Y']
percentage_dead = round((x['Fatal (Y/N)'].value_counts()[0])/len(df_ny)*100)
print("El porcentaje de muertes por ataque es de un", percentage_dead, "%")
# Out:
# El porcentaje de muertes por ataque es de un 19 %

# %%
# NOS CARGAMOS LAS FILAS EN LAS QUE YEAR SEA == 0

#df.drop(df.loc[df['Year'] == 'UNKNOWN'].index[0], axis = 0, inplace = True)
#df_ny.drop(df_ny.loc[df['Year'] == 0].index[0], axis = 0, inplace = True)

# %%
df_ny = df_ny.drop(df_ny.loc[df_ny['Year'] == 0].index[0], axis = 0, inplace = True)

# %%
df_ny.loc[df_ny['Year'] == 0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8752/395184428.py in <module>
# ----> 1 df_ny.loc[df_ny['Year'] == 0]
#
# AttributeError: 'NoneType' object has no attribute 'loc'

# %%
df_ny.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8752/1109120080.py in <module>
# ----> 1 df_ny.shape
#
# AttributeError: 'NoneType' object has no attribute 'shape'
